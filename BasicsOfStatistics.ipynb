# %% [markdown]
# # Basics Of Statistics

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
DATASET_SIZE = 1000

x = np.linspace(-1.0, 1.0, DATASET_SIZE)

# %%
print(x.shape)
print(x.ndim)
print(len(x))
# Out:
# (1000,)
# 1
# 1000

# %% [markdown]
# ## Generate Sythtetic Toy Data
# $y=ax+b$

# %%
y = 3 * x + 5

print(y.shape)
print(y.ndim)
print(len(y))
# Out:
# (1000,)
# 1
# 1000

# %%
plt.plot(x, y)
plt.title('Toy Synthetic Data')
plt.xlabel('X')
plt.ylabel('Y')
# Out:
# Text(0, 0.5, 'Y')

# %% [markdown]
# ## Add Noise

# %%
noise = np.random.randn(DATASET_SIZE)

_ = plt.hist(noise, bins=30)
plt.title('Distribution of Gaussian (Normal) Noise')
# Out:
# Text(0.5, 1.0, 'Distribution of Gaussian (Normal) Noise')

# %%
y = y + 0.1*np.random.randn(len(y))

# %%
plt.plot(x, y)
plt.title('Toy Synthetic Data with Noise')
plt.xlabel('X')
plt.ylabel('Y')
plt.grid('on')

# %% [markdown]
# ## Move Center of Data

# %%
y = y + 10

plt.plot(x, y)
plt.title('Toy Synthetic Data with Noise SHIFTED')
plt.xlabel('X')
plt.ylabel('Y')
plt.grid('on')

# %%
y = y - 50

plt.plot(x, y)
plt.title('Toy Synthetic Data with Noise SHIFTED')
plt.xlabel('X')
plt.ylabel('Y')
plt.grid('on')

# %% [markdown]
# ## Mean
# $\mu = \frac{1}{N} \sum_{i=1}^{N} x_i$

# %%
mean_1 = np.sum(y) / len(y)
mean_2 = np.mean(y)
mean_3 = y.mean()

print(f'Mean manual: {mean_1:.4f}')
print(f'Mean with np.mean: {mean_2:.4f}')
print(f'Mean with y.mean(): {mean_3:.4f}')
# Out:
# Mean manual: -35.0028
# Mean with np.mean: -35.0028
# Mean with y.mean(): -35.0028

# %% [markdown]
# ## Zero Mean

# %%
y = y - y.mean()

plt.plot(x, y)
plt.title('Toy Synthetic Data with Noise Zero Mean')
plt.xlabel('X')
plt.ylabel('Y')
plt.grid('on')

# %% [markdown]
# ## Variance ($\sigma^2$), Standart Deviation ($\sigma$)
# $\sigma^2 = \frac{1}{N} \sum_{i=1}^{N} (x_i - \mu)^2$
#
# $\sigma = \sqrt{\sigma^2}$

# %%
def calculate_variance(array):
    zero_mean = array - array.mean()
    sigma2 = np.mean(zero_mean ** 2)
    return sigma2

# %%
variance_1 = y.var()
variance_2 = calculate_variance(y)

print(f'Variance y.var(): {variance_1:.4f}')
print(f'Variance manual: {variance_2:.4f}')
# Out:
# Variance y.var(): 3.0111
# Variance manual: 3.0111

# %%
std_1 = y.std()
std_2 = np.sqrt(variance_2)

print(f'Standart deviation y.std(): {std_1:.4f}')
print(f'Standart deviation manual: {std_2:.4f}')
# Out:
# Standart deviation y.std(): 1.7353
# Standart deviation manual: 1.7353

# %% [markdown]
# ## Variance for Different Data

# %%
freq = 1
DATASET_SIZE = 1000

x = np.linspace(-1.0, 1.0, DATASET_SIZE)

y_2 = np.sin(2*np.pi*freq*x) + 0.1*np.random.randn(len(x))

print(f'Std: {y_2.std():.4f}')
print(f'Var: {y_2.var():.4f}')


plt.plot(x, y_2)
plt.title('Sine Data')
plt.xlabel('X')
plt.ylabel('Y')
plt.grid('on')
# Out:
# Std: 0.7121
# Var: 0.5071

# %%
freq = 1
DATASET_SIZE = 1000

x = np.linspace(-1.0, 1.0, DATASET_SIZE)

y_2 = np.sin(2*np.pi*freq*x) + x + 0.1*np.random.randn(len(x))

print(f'Std: {y_2.std():.4f}')
print(f'Var: {y_2.var():.4f}')


plt.plot(x, y_2)
plt.title('Sine Data with Trend')
plt.xlabel('X')
plt.ylabel('Y')
plt.grid('on')
# Out:
# Std: 0.7293
# Var: 0.5319

# %%
freq = 1
DATASET_SIZE = 1000

x = np.linspace(-1.0, 1.0, DATASET_SIZE)

y_2 = x**2 + x + 0.1*np.random.randn(len(x))

print(f'Std: {y_2.std():.4f}')
print(f'Var: {y_2.var():.4f}')


plt.plot(x, y_2)
plt.title('Data')
plt.xlabel('X')
plt.ylabel('Y')
plt.grid('on')
# Out:
# Std: 0.6602
# Var: 0.4359

# %%
DATASET_SIZE = 1000

x = np.linspace(-1.0, 1.0, DATASET_SIZE)

y_2 = 10.0*(x**3) + x**2 + x + 0.1*np.random.randn(len(x))

print(f'Std: {y_2.std():.4f}')
print(f'Var: {y_2.var():.4f}')


plt.plot(x, y_2)
plt.title('Data')
plt.xlabel('X')
plt.ylabel('Y')
plt.grid('on')
# Out:
# Std: 4.3341
# Var: 18.7843

# %% [markdown]
# ## Outlier

# %%
y = np.random.randn(len(x))

print(f'Std: {y.std():.4f}')
print(f'Var: {y.var():.4f}')

plt.plot(x, y)
plt.title('Data')
plt.xlabel('X')
plt.ylabel('Y')
plt.grid('on')
# Out:
# Std: 1.0313
# Var: 1.0636

# %%
SPIKE_AMOUNT = 10
y[100:120] = y[100:120] + SPIKE_AMOUNT

print(f'Std: {y.std():.4f}')
print(f'Var: {y.var():.4f}')

plt.plot(x, y)
plt.title('Data with Outliers (Spike)')
plt.xlabel('X')
plt.ylabel('Y')
plt.grid('on')
# Out:
# Std: 1.7483
# Var: 3.0565

# %% [markdown]
# ## Percentiles

# %%
percentiles = np.percentile(y, [25, 50, 75])

print('25th percentile (Q1):', percentiles[0])
print('50th percentile (Median):', percentiles[1])
print('75th percentile (Q3):', percentiles[2])
# Out:
# 25th percentile (Q1): -0.6214201188320783
# 50th percentile (Median): 0.06627844077268698
# 75th percentile (Q3): 0.772179801187695

# %%
percentiles = np.percentile(y, [95, 97, 99])

print('95th percentile:', percentiles[0])
print('97th percentile:', percentiles[1])
print('99th percentile:', percentiles[2])
# Out:
# 95th percentile: 1.8648257927509628
# 97th percentile: 2.54800909703002
# 99th percentile: 10.075964215083333

# %% [markdown]
# ## Basic Outlier Detection

# %%
PERCENTILE = 99
upper_threshold = np.percentile(y, PERCENTILE)
print(f'Upper threshold: {upper_threshold:.4f}')


# Get the y values of outliers
outliers_y = y[y>=upper_threshold]
# Get the x indices of outliers
outliers_x = x[np.argwhere(y>=upper_threshold)]
print(f'Outlier values: {outliers_y}')


plt.plot(x, y, c='blue', alpha=0.4, label='actual')
plt.scatter(outliers_x, outliers_y, c='red', alpha=0.9, label='outliers')
plt.legend()
# Out:
# Upper threshold: 10.0760
# Outlier values: [12.33766388 10.99927698 10.34372484 12.01137731 11.32681828 10.51372253
#  10.40583547 11.39281998 11.06849304 11.03997841]
